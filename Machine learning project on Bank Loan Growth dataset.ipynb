# %% [markdown]
# # Machine Learning project on bank loan growth rate

# %% [markdown]
# ## Import Impotant libraries

# %%
# Import Pandas 
# This library helps us to convert different data files (Structured or semi structured) into pandas dataframe.
import pandas as pd

# Import Numpy
# This library helps us to perform different numerical and statstical operation on different data structure.
import numpy as np

# Import seaborn and matplotlib 
# These both libraries help us to create and visualize
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset

# %%
# Load the file from local system
df_bank_loan_growth = pd.read_csv("bank_loan_growth.csv")

# %%
# Check the data set
df_bank_loan_growth
# Out:
#                region      bank bank_type  year  month    loan_type  \
# 0      Andhra Pradesh  Yes Bank   Private  2015      1       Retail
# 1      Andhra Pradesh  Yes Bank   Private  2015      2         MSME
# 2      Andhra Pradesh  Yes Bank   Private  2015      3       Retail
# 3      Andhra Pradesh  Yes Bank   Private  2015      4         MSME
# 4      Andhra Pradesh  Yes Bank   Private  2015      5  Agriculture
# ...               ...       ...       ...   ...    ...          ...
# 47515     Lakshadweep       SBI    Public  2025      8       Retail
# 47516     Lakshadweep       SBI    Public  2025      9       Retail
# 47517     Lakshadweep       SBI    Public  2025     10  Agriculture
# 47518     Lakshadweep       SBI    Public  2025     11  Agriculture
# 47519     Lakshadweep       SBI    Public  2025     12       Retail
#
#        credit_growth_rate  repo_rate  crr  deposit_growth_rate  lending_rate  \
# ...

# %% [markdown]
# ### Data Overview

# %%
# Show first 5 observations of the Data
df_bank_loan_growth.head()
# Out:
#            region      bank bank_type  year  month    loan_type  \
# 0  Andhra Pradesh  Yes Bank   Private  2015      1       Retail
# 1  Andhra Pradesh  Yes Bank   Private  2015      2         MSME
# 2  Andhra Pradesh  Yes Bank   Private  2015      3       Retail
# 3  Andhra Pradesh  Yes Bank   Private  2015      4         MSME
# 4  Andhra Pradesh  Yes Bank   Private  2015      5  Agriculture
#
#    credit_growth_rate  repo_rate  crr  deposit_growth_rate  lending_rate  \
# 0            4.517568       7.75  3.0             4.225131     11.222130
# 1            2.218194       6.00  3.5             5.123265      9.691752
# 2           11.582880       4.00  3.5             1.634815      6.860410
# 3            9.173729       4.00  6.0                  NaN      6.234783
# 4           11.267665       5.50  4.0             6.477163      8.181564
#
#    gdp_growth  inflation_rate  consumer_confidence_index  \
# 0    5.103439        7.138376                  75.171024
# ...

# %%
# Show the shape of the data
df_bank_loan_growth.shape
# Out:
# (47520, 19)

# %% [markdown]
# **Interpretation**
#  - We have 47520 rows
#  - We have 10 columns

# %%
# Show the basic info of the data
df_bank_loan_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47520 entries, 0 to 47519
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   region                     47520 non-null  object
#  1   bank                       47520 non-null  object
#  2   bank_type                  47520 non-null  object
#  3   year                       47520 non-null  int64
#  4   month                      47520 non-null  int64
#  5   loan_type                  47520 non-null  object
#  6   credit_growth_rate         46094 non-null  float64
#  7   repo_rate                  46570 non-null  float64
#  8   crr                        46570 non-null  float64
#  9   deposit_growth_rate        46094 non-null  float64
#  10  lending_rate               46094 non-null  float64
#  11  gdp_growth                 46570 non-null  float64
#  12  inflation_rate             46570 non-null  float64
# ...

# %%
# Justify the basic statistics of data
df_bank_loan_growth.describe().T
# Out:
#                              count           mean            std      min  \
# year                       47520.0    2020.000000       3.162311   2015.0
# month                      47520.0       6.500000       3.452089      1.0
# credit_growth_rate         46094.0      10.024275       5.032988    -10.0
# repo_rate                  46570.0       6.002534       1.225457      4.0
# crr                        46570.0       4.507591       0.997238      3.0
# deposit_growth_rate        46094.0       7.997566       4.027043     -5.0
# lending_rate               46094.0       9.002405       1.368448      6.0
# gdp_growth                 46570.0       6.004643       2.315736      2.0
# inflation_rate             46570.0       5.005933       1.732158      2.0
# consumer_confidence_index  46094.0     100.161519      29.128337     50.0
# investment_sentiment       46094.0      59.899719      11.602800     40.0
# npa_ratio                  46094.0       0.516143       0.520608      0.0
# ...

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# ### Null value handing

# %%
# Show the count of null records in the data
df_bank_loan_growth.isnull().sum()
# Out:
# region                          0
# bank                            0
# bank_type                       0
# year                            0
# month                           0
# loan_type                       0
# credit_growth_rate           1426
# repo_rate                     950
# crr                           950
# deposit_growth_rate          1426
# lending_rate                 1426
# gdp_growth                    950
# inflation_rate                950
# consumer_confidence_index    1426
# investment_sentiment         1426
# npa_ratio                    1426
# liquidity_ratio              1426
# global_trade_index           1426
# bank_size                    1426
# dtype: int64

# %% [markdown]
# **Interpretation**
#  - We have 1426 null values in credit_growth_rate.
#  - We have 950 null values in repo_rate.
#  - We have 950 null values in crr.
#  - We have 1426 null values in deposit_growth_rate.
#  - We have 1426 null values in lending_rate.
#  - We have 950 null values in gdp_rate.
#  - We have 950 null values in inflation_rate.
#  - We have 1426 null values in consumer_confidence_index.
#  - We have 1426 null values in investment_sentiment.
#  - We have 1426 null values in npa_ratio.
#  - We have 1426 null values in liquidity_ratio.
#  - We have 1426 null values in global_trade_index.
#  - We have 1426 null values in bank_size.

# %%
# Find the percentage of missing records
df_bank_loan_growth.isnull().sum()/len(df_bank_loan_growth)*100
# Out:
# region                       0.000000
# bank                         0.000000
# bank_type                    0.000000
# year                         0.000000
# month                        0.000000
# loan_type                    0.000000
# credit_growth_rate           3.000842
# repo_rate                    1.999158
# crr                          1.999158
# deposit_growth_rate          3.000842
# lending_rate                 3.000842
# gdp_growth                   1.999158
# inflation_rate               1.999158
# consumer_confidence_index    3.000842
# investment_sentiment         3.000842
# npa_ratio                    3.000842
# liquidity_ratio              3.000842
# global_trade_index           3.000842
# bank_size                    3.000842
# dtype: float64

# %%
# List of numerical columns where we want to drop rows with null values
columns_with_nulls = [
    'credit_growth_rate', 'repo_rate', 'crr', 'deposit_growth_rate',
    'lending_rate', 'gdp_growth', 'inflation_rate',
    'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
    'liquidity_ratio', 'global_trade_index', 'bank_size'
]

# Drop rows where any of these columns have NaN values
df_bank_loan_growth = df_bank_loan_growth.dropna(subset=columns_with_nulls)

# %%
# Do the authentic check
df_bank_loan_growth.isnull().sum()
# Out:
# region                       0
# bank                         0
# bank_type                    0
# year                         0
# month                        0
# loan_type                    0
# credit_growth_rate           0
# repo_rate                    0
# crr                          0
# deposit_growth_rate          0
# lending_rate                 0
# gdp_growth                   0
# inflation_rate               0
# consumer_confidence_index    0
# investment_sentiment         0
# npa_ratio                    0
# liquidity_ratio              0
# global_trade_index           0
# bank_size                    0
# dtype: int64

# %%
df_bank_loan_growth = df_bank_loan_growth.reset_index(drop=True)

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ## Univariate Analysis

# %%
# Make a data frame for numerical data
df_num = df_bank_loan_growth.select_dtypes(include = 'number')

# %%
# Make a data frame for categorical data
df_cat = df_bank_loan_growth.select_dtypes(include = 'object')

# %%
# Function to get the quarter from a month
def get_monthly_quarter(month):
    if 1 <= month <= 3:
        return 1
    elif 4 <= month <= 6:
        return 2
    elif 7 <= month <= 9:
        return 3
    elif 10 <= month <= 12:
        return 4
    else:
        return np.nan

# Function to map months to seasons
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Summer'
    elif month in [6, 7, 8, 9]:
        return 'Monsoon'
    elif month in [10, 11]:
        return 'Autumn'
    else:
        return 'Unknown'

# Create new columns in df_bank_loan_growth
df_bank_loan_growth['monthly_quarter'] = df_bank_loan_growth['month'].apply(get_monthly_quarter).astype(int)
df_bank_loan_growth['season'] = df_bank_loan_growth['month'].apply(get_season)

# %%
# Make a data frame for numerical data
df_num = df_bank_loan_growth.select_dtypes(include = 'number')

# %%
# Make a data frame for categorical data
df_cat = df_bank_loan_growth.select_dtypes(include = 'object')

# %%
# Show the first five observations of numerical data
df_num.head()
# Out:
#    year  month  credit_growth_rate  repo_rate  crr  deposit_growth_rate  \
# 0  2015      1            4.517568       7.75  3.0             4.225131
# 1  2015      2            2.218194       6.00  3.5             5.123265
# 2  2015      3           11.582880       4.00  3.5             1.634815
# 3  2015      7           14.364200       5.75  4.0            15.747058
# 4  2015      8           11.106322       5.75  4.0            10.053820
#
#    lending_rate  gdp_growth  inflation_rate  consumer_confidence_index  \
# 0     11.222130    5.103439        7.138376                  75.171024
# 1      9.691752    5.642978        3.329605                 110.067607
# 2      6.860410    7.737306        2.641810                  80.095709
# 3      8.471438    3.958564        3.129653                  58.458224
# 4      9.226140    3.732178        7.115658                 115.850838
#
#    investment_sentiment  npa_ratio  liquidity_ratio  global_trade_index  \
# ...

# %%
# Show the first five observations of categorical data
df_cat.head()
# Out:
#            region      bank bank_type    loan_type   season
# 0  Andhra Pradesh  Yes Bank   Private       Retail   Winter
# 1  Andhra Pradesh  Yes Bank   Private         MSME   Winter
# 2  Andhra Pradesh  Yes Bank   Private       Retail   Summer
# 3  Andhra Pradesh  Yes Bank   Private  Agriculture  Monsoon
# 4  Andhra Pradesh  Yes Bank   Private         MSME  Monsoon

# %% [markdown]
# ### Perform Univariate analysis on numerical data

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For Year Column

# %%
# Show the minimum
df_num.year.min()
# Out:
# 2015

# %%
# Show the maximum
df_num.year.max()
# Out:
# 2025

# %%
# Show the Average
df_num.year.mean().round(2)
# Out:
# 2020.0

# %%
# Show the distribution of the single numerical column
df_num.year.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('year')
plt.title('Distribution of year', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Minimum year present in the dataset = 2015
#  - Maximum year present in the dataset = 2025
#  - The dataset covers a continuous 11-year period
#  - The distribution of `year` is uniform, indicating equal number of records across all years
#  - The KDE plot shows evenly spaced peaks, confirming each year has roughly the same density
#  - No records exist outside the expected year range (i.e., no data before 2015 or after 2025)
# odels.

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For Month Column

# %%
# Show the minimun
df_num.month.min()
# Out:
# 1

# %%
# Show the maximum
df_num.month.max()
# Out:
# 12

# %%
# Show the average
df_num.month.mean().round(2)
# Out:
# 6.51

# %%
# Show the distribution of the single numerical column
df_num.month.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.title('Distribution of Month', color='#1f77b4')
plt.xlabel('month')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Minimum month present in the dataset = 1
#  - Maximum month present in the dataset = 12
#  - The dataset includes all 12 months, indicating data is spread evenly across the calendar year
#  - The KDE plot shows a uniform pattern with nearly equal density for each month
#  - This suggests that job postings (or observations) are consistently distributed throughout the year
#  - No records are present outside the valid month range (i.e., 1 to 12)

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For credit_growth_rate Column

# %%
# Show the minimum
df_num.credit_growth_rate.min()
# Out:
# -10.0

# %%
# Show the maximum
df_num.credit_growth_rate.max()
# Out:
# 28.69326147112151

# %%
# Show the Average
df_num.credit_growth_rate.mean().round(2)
# Out:
# 10.02

# %%
# Show the distribution of the single numerical column
df_num.credit_growth_rate.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('credit_growth_rate')
plt.title('Distribution of credit_growth_rate', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Minimum observed `credit growth rate` = -10
#  - Maximum observed `credit growth rate` = 28.69326147112151
#  - The average `credit growth rate` lies around 10
#  - The distribution is approximately normal (bell-shaped)
#  - Most credit growth rates are concentrated between 5 and 15
#  - Very few extreme values exist on both negative and positive sides, suggesting mild skewness but no heavy outliers.

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For repo_rate column

# %%
# Show the minimum
df_num.repo_rate.min()
# Out:
# 4.0

# %%
# Show the maximin
df_num.repo_rate.max()
# Out:
# 8.0

# %%
# Show the average
df_num.repo_rate.mean().round(2)
# Out:
# 6.0

# %%
# Show the distribution of the single numerical column
df_num.repo_rate.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('repo_rate')
plt.title('Distribution of repo_rate', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Minimum observed `repo rate` = 4
# - Maximum observed `repo rate` = 8
# - The average `repo rate` =  6
# - The distribution is relatively flat and uniform between 4 and 8
# - Most repo rates are evenly distributed within this range, with sharp drop-offs outside
# - Very few extreme values exist outside 4–8, suggesting stability and controlled variation in policy rates over time

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For crr column

# %%
# Show the minimum
df_num.crr.min()
# Out:
# 3.0

# %%
# Show the maximum
df_num.crr.max()
# Out:
# 6.0

# %%
# Show the average
df_num.crr.mean().round(2)
# Out:
# 4.51

# %%
# Show the distribution of the single numerical column
df_num.crr.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('crr')
plt.title('Distribution of crr', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Minimum observed `crr` = 3
# - Maximim observed `crr` = 6
# - Average `crr` lies around 4.51
# - The `crr` (Cash Reserve Ratio) distribution shows a periodic oscillating pattern
# - Multiple sharp peaks suggest a limited set of frequently repeated CRR values (likely policy-defined)
# - The data lies within a narrow band (approx. 3%–6.5%), indicating regulatory consistency
# - This kind of discrete variation is common in macroeconomic policy variables
# - KDE may exaggerate smoothness; a histogram might be more appropriate here

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For deposit_growth_rate column

# %%
# Show the minimum
df_num.deposit_growth_rate.min()
# Out:
# -5.0

# %%
# Show the maximin
df_num.deposit_growth_rate.max()
# Out:
# 25.0

# %%
# Show the average
df_num.deposit_growth_rate.mean().round(2)
# Out:
# 7.99

# %%
# Show the distribution of the single numerical column
df_num.deposit_growth_rate.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('deposit_growth_rate')
plt.title('Distribution of deposit_growth_rate', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Minimum observed `deposit growth rate` = -5
# - Maximum observed `deposit growth rate` = 25
# - The average`deposit growth rate` lies around 8
# - The distribution is slightly right-skewed, with a peak near 8
# - Most deposit growth rates are concentrated between 5 and 15
# - A few outliers exist on both negative and high positive sides, indicating occasional volatility

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For lending_rate column

# %%
# Show the minimum
df_num.lending_rate.min()
# Out:
# 6.0

# %%
# Show the maximin
df_num.lending_rate.max()
# Out:
# 12.0

# %%
# Show the average
df_num.lending_rate.mean().round(2)
# Out:
# 9.0

# %%
# Show the distribution of the single numerical column
df_num.lending_rate.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('lending_rate')
plt.title('Distribution of lending_rate', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Minimum observed `lending rate` =  6
# - Maximum observed `lending rate` =  12
# - The average `lending rate` is 9
# - The distribution is moderately bell-shaped with slight flatness
# - Most lending rates are concentrated between 7 and 11
# - Very few extreme values exist outside this range, indicating a controlled lending environment

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For gdp_growth column

# %%
# Show the minimum
df_num.gdp_growth.min()
# Out:
# 2.0

# %%
# Show the maximin
df_num.gdp_growth.max()
# Out:
# 10.0

# %%
# Show the average
df_num.gdp_growth.mean().round(2)
# Out:
# 6.01

# %%
# Show the distribution of the single numerical column
df_num.gdp_growth.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('gdp_growth')
plt.title('Distribution of gdp_growth', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Minimum `gdp growth` is 2
# - Maximum `gdp growth` is 10
# - The average `gdp growth` is 6.01
# - The `gdp_growth` distribution shows a near-uniform shape between ~3% and ~10%
# - The flat plateau indicates GDP growth rates are fairly evenly distributed in that range
# - Sharp rises and falls at the edges suggest strict lower and upper bounds in the dataset
# - This could reflect real-world economic stability or data truncation
# - Such a distribution is atypical in natural processes—warrants further data quality review

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For inflation_rate column

# %%
# Show the minimum
df_num.inflation_rate.min()
# Out:
# 2.0

# %%
# Show the maximum
df_num.inflation_rate.max()
# Out:
# 8.0

# %%
# Show the Average
df_num.inflation_rate.mean().round(2)
# Out:
# 5.01

# %%
# Show the distribution of the single numerical column
df_num.inflation_rate.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('inflation_rate')
plt.title('Distribution of inflation_rate', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Minimum observed inflation rate ≈ 0
# - Maximum observed inflation rate ≈ 10
# - The average inflation rate lies between 4 and 6
# - The distribution is nearly flat and uniform between 2 and 8
# - Most inflation rates are evenly spread within this range, with sharp drop-offs outside
# - Very few extreme values exist outside 2–8, indicating consistent inflation trends over time

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For consumer_confidence_index column

# %%
# Show the minimum
df_num.consumer_confidence_index.min()
# Out:
# 50.0

# %%
# Show the maximum
df_num.consumer_confidence_index.max()
# Out:
# 150.0

# %%
# Show the Average
df_num.consumer_confidence_index.mean().round(2)
# Out:
# 100.05

# %%
# Show the distribution of the single numerical column
df_num.consumer_confidence_index.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('consumer_confidence_index')
plt.title('Distribution of consumer_confidence_index', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Consumer confidence index ranges approximately from 0 to 200
# - Most values lie between 50 and 150, forming a flat, plateau-like shape
# - The index is evenly distributed within that central range, indicating stable consumer sentiment
# - Slight peaks near 90–130 suggest mildly stronger confidence around those values
# - Very few data points exist below 50 or above 150, implying rare extreme pessimism or optimism

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For investment_sentiment Column

# %%
# Show the minimum
df_num.investment_sentiment.min()
# Out:
# 40.0

# %%
# Show the maximum
df_num.investment_sentiment.max()
# Out:
# 80.0

# %%
# Show the average
df_num.investment_sentiment.mean().round(2)
# Out:
# 59.92

# %%
# Show the distribution of the single numerical column
df_num.investment_sentiment.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('investment_sentiment')
plt.title('Distribution of investment_sentiment', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - Investment sentiment values range roughly from 20 to 100
# - Most data points are concentrated between 40 and 80, with a relatively flat distribution
# - Slight peaks occur near 55–60, indicating moderate investor optimism is common
# - Sharp drop-offs beyond 80 and below 40 suggest rare extreme pessimism or confidence
# - The uniformity between 45 and 75 suggests stable and balanced investor sentiment over time

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For npa_ratio Column

# %%
# Show the minimum
df_num.npa_ratio.min()
# Out:
# 0.0

# %%
# Show the maximum
df_num.npa_ratio.max()
# Out:
# 5.082050776907181

# %%
# Show the average
df_num.npa_ratio.mean().round(2)
# Out:
# 0.52

# %%
# Show the distribution of the single numerical column
df_num.npa_ratio.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('npa_ratio')
plt.title('Distribution of npa_ratio', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - The NPA (Non-Performing Asset) ratio is heavily right-skewed
# - Most values are tightly concentrated around 0, indicating that a majority of banks maintain low NPA levels
# - The sharp peak at 0 suggests a common target or healthy benchmark is being maintained
# - The long right tail indicates that a few institutions exhibit significantly higher NPA ratios
# - Outliers beyond 4 may indicate financial distress or mismanagement in select cases

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For liquidity_ratio Column

# %%
# Show the minimum
df_num.liquidity_ratio.min()
# Out:
# 80.0

# %%
# Show the maximum
df_num.liquidity_ratio.max()
# Out:
# 167.97434210331787

# %%
# Show the distribution of the single numerical column
df_num.liquidity_ratio.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('liquidity_ratio')
plt.title('Distribution of liquidity_ratio', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - The liquidity_ratio distribution is approximately normal (bell-shaped and symmetric)
# - Most values cluster around the mean (~120), indicating a common liquidity benchmark among institutions
# - There are no extreme outliers, suggesting stable liquidity management across the dataset
# - Slight tapering tails imply moderate variation but controlled dispersion
# - Such a distribution is often ideal in financial health assessments, reflecting consistent liquidity coverage

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For global_trade_index Column

# %%
# Show the minimum
df_num.global_trade_index.min()
# Out:
# 50.0

# %%
# Show the maximum
df_num.global_trade_index.max()
# Out:
# 150.0

# %%
# Show the average
df_num.global_trade_index.mean().round(2)
# Out:
# 100.0

# %%
# Show the distribution of the single numerical column
df_num.global_trade_index.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('global_trade_index')
plt.title('Distribution of global_trade_index', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - The global_trade_index shows a symmetrical, unimodal distribution centered around ~100
# - This indicates that global trade levels tend to cluster around a typical mid-range value
# - The bell-shaped KDE curve suggests normality, implying consistent global trade performance
# - There are minimal outliers or skewness, indicating stable international trade trends in the dataset
# - Such distribution patterns are valuable for modeling global macroeconomic behavior reliably

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For bank_size Column

# %%
# Show the minimum
df_num.bank_size.min()
# Out:
# 11392.041376180114

# %%
# Show the maximum
df_num.bank_size.max()
# Out:
# 5000000.0

# %%
# Show the average
df_num.bank_size.mean().round(2)
# Out:
# 796652.85

# %%
# Show the distribution of the single numerical column
df_num.bank_size.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('bank_size')
plt.title('Distribution of bank_size', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - The `bank_size` distribution is highly right-skewed with a sharp peak near zero
# - Most banks in the dataset are relatively small in size, concentrated close to the lower end
# - A long right tail and secondary bump suggest the presence of a few very large banks (outliers)
# - This reflects typical financial industry characteristics where a few institutions dominate in size
# - Log transformation may help normalize the data for regression or ML applications

# %%
# Show the numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [markdown]
# ### For monthly_quarter Column

# %%
# Show the minimum
df_num.monthly_quarter.min()
# Out:
# 1

# %%
# Show the maximum
df_num.monthly_quarter.max()
# Out:
# 4

# %%
# Show the average
df_num.monthly_quarter.mean().round(2)
# Out:
# 2.5

# %%
# Show the distribution of the single numerical column
df_num.monthly_quarter.plot(kind='kde', color='#1f77b4')  # Kernel Density Plot
plt.grid()
plt.xlabel('monthly_quarter')
plt.title('Distribution of monthly_quarter', color='#1f77b4')
plt.show()

# %% [markdown]
# **Interpretation**
# - The `monthly_quarter` distribution shows four sharp, evenly spaced peaks
# - Each peak corresponds to a quarter, indicating clear separation by months
# - The distribution is uniform, suggesting balanced data across all quarters
# - No outliers or skewness is present in the distribution
# - This regular pattern aligns with structured time-based financial repoting

# %% [markdown]
# ### Perform Univariate analysis on categorical data

# %%
# Show categorical data
df_cat.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'loan_type', 'season'], dtype='object')

# %% [markdown]
# ### For region column

# %%
# Show the counts
df_cat.region.value_counts()
# Out:
# region
# Meghalaya               958
# Madhya Pradesh          946
# Arunachal Pradesh       943
# Dadra & Nagar Haveli    943
# Lakshadweep             942
# Telangana               940
# Ladakh                  939
# Manipur                 937
# Tamil Nadu              937
# Delhi                   936
# Kerala                  935
# Chhattisgarh            935
# Maharashtra             931
# Assam                   931
# Jharkhand               930
# Andaman & Nicobar       929
# Sikkim                  929
# Nagaland                928
# Rajasthan               927
# Jammu & Kashmir         924
# Andhra Pradesh          924
# Uttarakhand             923
# Bihar                   922
# Himachal Pradesh        921
# Uttar Pradesh           920
# Karnataka               919
# Haryana                 917
# West Bengal             915
# Gujarat                 913
# Odisha                  913
# Mizoram                 912
# Chandigarh              911
# Puducherry              910
# ...

# %%
# Plot the Graph
df_cat.region.value_counts().plot(kind = "bar", color='#1f77b4', rot=90)
plt.title(" Count of Regions ")
plt.xlabel("Name of the region")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - People from Meghalaya               958
#  - People from Madhya Pradesh          946
#  - People from Arunachal Pradesh       943
#  - People from Dadra & Nagar Haveli    943
#  - People from Lakshadweep             942
#  - People from Telangana               940
#  - People from Ladakh                  939
#  - People from Manipur                 937
#  - People from Tamil Nadu              937
#  - People from Delhi                   936
#  - People from Kerala                  935
#  - People from Chhattisgarh            935
#  - People from Maharashtra             931
#  - People from Assam                   931
#  - People from Jharkhand               930
#  - People from Andaman & Nicobar       929
#  - People from Sikkim                  929
#  - People from Nagaland                928
#  - People from Rajasthan               927
#  - People from Jammu & Kashmir         924
#  - People from Andhra Pradesh          924
#  - People from Uttarakhand             923
#  - People from Bihar                   922
#  - People from Himachal Pradesh        921

# %%
# Show the columns
df_cat.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'loan_type', 'season'], dtype='object')

# %% [markdown]
# ### For bank column

# %%
# Show the counts
df_cat.bank.value_counts()
# Out:
# bank
# Yes Bank         2678
# SBI              2673
# IDBI             2514
# Canara           2468
# Kotak            2439
# BoB              2425
# Axis             2411
# IndusInd         2385
# ICICI            2321
# Bank of India    2310
# PNB              2279
# UCO Bank         2271
# Union Bank       2205
# HDFC             1970
# Name: count, dtype: int64

# %%
# Plot the Graph
df_cat.bank.value_counts().plot(kind = "bar", color='#1f77b4', rot=90)
plt.title(" Counts of Bank ")
plt.xlabel("Name of the bank")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Count of Yes Bank         2678
#  - Count of SBI              2673
#  - Count of IDBI             2514
#  - Count of Canara           2468
#  - Count of Kotak            2439
#  - Count of BoB              2425
#  - Count of Axis             2411
#  - Count of IndusInd         2385
#  - Count of ICICI            2321
#  - Count of Bank of India    2310
#  - Count of PNB              2279
#  - Count of UCO Bank         2271
#  - Count of Union Bank       2205
#  - Count of HDFC             1970

# %%
# Show the columns
df_cat.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'loan_type', 'season'], dtype='object')

# %% [markdown]
# ### For bank_type

# %%
# Show the count
df_cat.bank_type.value_counts()
# Out:
# bank_type
# Public     19145
# Private    14204
# Name: count, dtype: int64

# %%
# Plot the Graph
df_cat.bank_type.value_counts().plot(kind = "bar", color='#1f77b4', rot=0)
plt.title(" count of Bank types ")
plt.xlabel("Bank types")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Number of Public bank: 19145
#  - Number of Private bank: 14204

# %%
# show the columns
df_cat.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'loan_type', 'season'], dtype='object')

# %% [markdown]
# ### For loan_type column

# %%
# Show the count
df_cat.loan_type.value_counts()
# Out:
# loan_type
# Retail         13317
# MSME           10018
# Corporate       6670
# Agriculture     3344
# Name: count, dtype: int64

# %%
# Plot the Graph
df_cat.loan_type.value_counts().plot(kind = "bar", color='#1f77b4', rot=0)
plt.title(" Count of loan_types")
plt.xlabel("loan types")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Number of Retail         13317
#  - Number of MSME           10018
#  - Number of Corporate       6670
#  - Number of Agriculture     3344

# %%
df_cat.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'loan_type', 'season'], dtype='object')

# %%
df_cat.season.value_counts()
# Out:
# season
# Monsoon    11139
# Summer      8348
# Winter      8300
# Autumn      5562
# Name: count, dtype: int64

# %%
# Plot the Graph
df_cat.season.value_counts().plot(kind = "bar", color='#1f77b4', rot=0)
plt.title(" Count of season")
plt.xlabel("season")
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Count of Monsoon    11139
#  - Count of Summer      8348
#  - Count of Winter      8300
#  - Count of Autumn      5562

# %% [markdown]
# ## Bivariate Analysis

# %%
# Show the Correlation Table between categrorical columns and numerical columns
df_num.corr()
# Out:
#                                year     month  credit_growth_rate  repo_rate  \
# year                       1.000000  0.002311           -0.002197  -0.004183
# month                      0.002311  1.000000            0.002396  -0.007907
# credit_growth_rate        -0.002197  0.002396            1.000000   0.007304
# repo_rate                 -0.004183 -0.007907            0.007304   1.000000
# crr                       -0.003211  0.009428           -0.007561  -0.007553
# deposit_growth_rate        0.006483  0.005443           -0.008157   0.006895
# lending_rate              -0.009113 -0.005115            0.010300   0.895902
# gdp_growth                 0.003590 -0.002276            0.001101   0.003574
# inflation_rate             0.015753 -0.001746            0.002667   0.004374
# consumer_confidence_index -0.005751  0.005383            0.004974   0.008640
# investment_sentiment      -0.004533  0.001450           -0.001497  -0.000926
# ...

# %%
# plot the scater plot between Exam_score and Attendance

sns.scatterplot(x="repo_rate", y="lending_rate", data=df_num, color='#1f77b4')
plt.title("Repo rate VS Lending rate")
plt.xlabel("Repo rate")
plt.ylabel("Lending rate")
plt.grid()
plt.show()

# %% [markdown]
# ### Bivariate analysis on 1 numerical snd 1 categorical column

# %%
# categorical columns
df_cat.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'loan_type', 'season'], dtype='object')

# %%
# numerical columns
df_num.columns
# Out:
# Index(['year', 'month', 'credit_growth_rate', 'repo_rate', 'crr',
#        'deposit_growth_rate', 'lending_rate', 'gdp_growth', 'inflation_rate',
#        'consumer_confidence_index', 'investment_sentiment', 'npa_ratio',
#        'liquidity_ratio', 'global_trade_index', 'bank_size',
#        'monthly_quarter'],
#       dtype='object')

# %% [raw]
# region
# bank
# bank_type
# loan_type
# season

# %% [raw]
# region,year
# bank,year
# bank_type,year
# loan_type,year
# season,year

# %%
# Region Vs Year
sns.barplot(x='region', y='year', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Year")
plt.xlabel("Region")
plt.ylabel("Year")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions
#  - The average Year is same across all around(2000), no effect on Year

# %%
# Bank VS Year
sns.barplot(x='bank', y='year', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Year")
plt.xlabel("Bank")
plt.ylabel("Year")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank
#  - The average Year is same across all around(2000), no effect on Year

# %%
# Bank type VS Year
sns.barplot(x='bank_type', y='year', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Year")
plt.xlabel("Bank Type")
plt.ylabel("Year")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Type
#  - The average Year is same across all around(2000), no effect on Year

# %%
#Loan Type vs Year
sns.barplot(x='loan_type', y='year', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Year")
plt.xlabel("Loan Type")
plt.ylabel("Year")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Type
#  - The average Year is same across all around(2000), no effect on Year

# %%
# Season vs Year
sns.barplot(x='season', y='year', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Year")
plt.xlabel("Season")
plt.ylabel("Year")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The average Year is same across all around(2000), no effect on Year

# %% [raw]
# region, month
# bank, month
# bank_type, month
# loan_type, month
# season, month

# %%
# Region vs Month
sns.barplot(x='region', y='month', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Month")
plt.xlabel("Region")
plt.ylabel("Month")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with some minute variations
#  - The average Month is similar across all (around 6.5), no effect on Month

# %%
# Bank VS Month
sns.barplot(x='bank', y='month', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Month")
plt.xlabel("Bank")
plt.ylabel("Month")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with some minute variations
#  - The average Month is similar across all (around 6.5), no effect on Month

# %%
# Bank VS Month
sns.barplot(x='bank', y='month', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Month")
plt.xlabel("Bank")
plt.ylabel("Month")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with some minute variations
#  - The average Month is similar across all (around 6.5), no effect on Month

# %%
# Bank Type VS Month
sns.barplot(x='bank_type', y='month', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Month")
plt.xlabel("Bank Type")
plt.ylabel("Month")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types
#  - The average Month is similar across all (around 6.5), no effect on Month

# %%
# Season VS Month
sns.barplot(x='season', y='month', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Month")
plt.xlabel("Season")
plt.ylabel("Month")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not balanced across all Seasons with some variations
#  - The average Month is similar across all (around 6.5), high effect on Month

# %% [raw]
# region, credit_growth_rate
# bank, credit_growth_rate
# bank_type, credit_growth_rate
# loan_type, credit_growth_rate

# %%
# Region VS Credit Growth Rate
sns.barplot(x='region', y='credit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Credit Growth Rate")
plt.xlabel("Region")
plt.ylabel("Credit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with some minute variations
#  - The average Credit Growth Rate is similar across all (9-11), minute effect on Credit Growth Rate

# %%
# Bank VS Credit Growth Rate
sns.barplot(x='bank', y='credit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Credit Growth Rate")
plt.xlabel("Bank")
plt.ylabel("Credit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with some minute variations
#  - The average Credit Growth Rate is similar across all (9-11), no effect on Credit Growth Rate

# %%
# Bank Type VS Credit Growth Rate
sns.barplot(x='bank_type', y='credit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Credit Growth Rate")
plt.xlabel("Bank Type")
plt.ylabel("Credit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types
#  - The average Credit Growth Rate is similar across all (9-11), no effect on Credit Growth Rate

# %%
# Loan Type VS Credit Growth Rate
sns.barplot(x='loan_type', y='credit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Credit Growth Rate")
plt.xlabel("Loan Type")
plt.ylabel("Credit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types
#  - The average Credit Growth Rate is similar across all (9-11), no effect on Credit Growth Rate

# %%
# Season VS Credit Growth Rate
sns.barplot(x='season', y='credit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Credit Growth Rate")
plt.xlabel("Season")
plt.ylabel("Credit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The average Credit Growth Rate is similar across all (9-11), no effect on Credit Growth Rate

# %% [raw]
# region, repo_rate
# bank, repo_rate
# bank_type, repo_rate
# loan_type, repo_rate

# %%
# Region VS Credit Growth Rate
sns.barplot(x='region', y='repo_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Repo Rate")
plt.xlabel("Region")
plt.ylabel("Repo Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with very minute variations
#  - The Repo Rate is similar across all (5.9-6.1), no effect on Repo Rate

# %%
# Bank VS Credit Growth Rate
sns.barplot(x='bank', y='repo_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Repo Rate")
plt.xlabel("Bank")
plt.ylabel("Repo Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with very minute variations
#  - The Repo Rate is similar across all (5.9-6.1), no effect on Repo Rate

# %%
# Bank Type VS Credit Growth Rate
sns.barplot(x='bank_type', y='repo_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Repo Rate")
plt.xlabel("Bank Type")
plt.ylabel("Repo Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types with very minute variations
#  - The Repo Rate is similar across all (5.9-6.1), no effect on Repo Rate

# %%
# Loan Type VS Credit Growth Rate
sns.barplot(x='loan_type', y='repo_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Repo Rate")
plt.xlabel("Loan Type")
plt.ylabel("Repo Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types with very minute variations
#  - The Repo Rate is similar across all (5.9-6.1), no effect on Repo Rate

# %%
# Season VS Credit Growth Rate
sns.barplot(x='season', y='repo_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Repo Rate")
plt.xlabel("Season")
plt.ylabel("Repo Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Season
#  - The Repo Rate is similar across all (5.9-6.1), no effect on Repo Rate

# %% [raw]
# region, crr
# bank, crr
# bank_type, crr
# loan_type, crr

# %%
# Region VS CRR
sns.barplot(x='region', y='crr', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs CRR")
plt.xlabel("Region")
plt.ylabel("CRR")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with very minute variations
#  - The CRR is similar across all (around 4.5), no effect on CRR

# %%
# Bank VS CRR
sns.barplot(x='bank', y='crr', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs CRR")
plt.xlabel("Bank")
plt.ylabel("CRR")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with very minute variations
#  - The CRR is similar across all (around 4.5), no effect on CRR

# %%
# Bank Type VS CRR
sns.barplot(x='bank_type', y='crr', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs CRR")
plt.xlabel("Bank Type")
plt.ylabel("CRR")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types with very minute variations
#  - The CRR is similar across all (around 4.5), no effect on CRR

# %%
# Loan Type VS CRR
sns.barplot(x='loan_type', y='crr', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs CRR")
plt.xlabel("Loan Type")
plt.ylabel("CRR")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types with very minute variations
#  - The CRR is similar across all (around 4.5), no effect on CRR

# %%
# Season VS CRR
sns.barplot(x='season', y='crr', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs CRR")
plt.xlabel("Season")
plt.ylabel("CRR")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons with very minute variations
#  - The CRR is similar across all (around 4.5), no effect on CRR

# %% [raw]
# region, deposit_growth_rate
# bank, deposit_growth_rate
# bank_type, deposit_growth_rate
# loan_type, deposit_growth_rate

# %%
# Region VS Deposit Growth Rate
sns.barplot(x='region', y='deposit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Deposit Growth Rate")
plt.xlabel("Region")
plt.ylabel("Deposit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with some variations
#  - The Deposit Growth Rate is similar across all (around 7.8-8.2), low effect on Deposit Growth Rate

# %%
# Bank VS Deposit Growth Rate
sns.barplot(x='bank', y='deposit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Deposit Growth Rate")
plt.xlabel("Bank")
plt.ylabel("Deposit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with some variations
#  - The Deposit Growth Rate is similar across all (around 7.8-8.2), low effect on Deposit Growth Rate

# %%
# Bank Type VS Deposit Growth Rate
sns.barplot(x='bank_type', y='deposit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Deposit Growth Rate")
plt.xlabel("Bank Type")
plt.ylabel("Deposit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types with some variations
#  - The Deposit Growth Rate is similar across all (around 7.8-8.2), low effect on Deposit Growth Rate

# %%
# Loan Type VS Deposit Growth Rate
sns.barplot(x='loan_type', y='deposit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Deposit Growth Rate")
plt.xlabel("Loan Type")
plt.ylabel("Deposit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types with some variations
#  - The Deposit Growth Rate is similar across all (around 7.8-8.2), low effect on Deposit Growth Rate

# %%
# Season VS Deposit Growth Rate
sns.barplot(x='season', y='deposit_growth_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Deposit Growth Rate")
plt.xlabel("Season")
plt.ylabel("Deposit Growth Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons with some variations
#  - The Deposit Growth Rate is similar across all (around 7.8-8.2), no effect on Deposit Growth Rate

# %% [raw]
# region, lending_rate
# bank, lending_rate
# bank_type, lending_rate
# loan_type, lending_rate

# %%
sns.barplot(x='region', y='lending_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Lending Rate")
plt.xlabel("Region")
plt.ylabel("Lending Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with minute variations
#  - The Lending Rate is similar across all (around 9), no effect on Lending Rate

# %%
sns.barplot(x='bank', y='lending_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Lending Rate")
plt.xlabel("Bank")
plt.ylabel("Lending Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with minute variations
#  - The Lending Rate is similar across all (around 9), no effect on Lending Rate

# %%
sns.barplot(x='bank_type', y='lending_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Lending Rate")
plt.xlabel("Bank Type")
plt.ylabel("Lending Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank types
#  - The Lending Rate is similar across all (around 9), no effect on Lending Rate

# %%
sns.barplot(x='loan_type', y='lending_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Lending Rate")
plt.xlabel("Loan Type")
plt.ylabel("Lending Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types
#  - The Lending Rate is similar across all (around 9), no effect on Lending Rate

# %%
sns.barplot(x='season', y='lending_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Lending Rate")
plt.xlabel("Season")
plt.ylabel("Lending Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The Lending Rate is similar across all (around 9), no effect on Lending Rate

# %% [raw]
# region, gdp_growth
# bank, gdp_growth
# bank_type, gdp_growth
# loan_type, gdp_growth

# %%
sns.barplot(x='region', y='gdp_growth', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs GDP Growth")
plt.xlabel("Region")
plt.ylabel("GDP Growth")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The GDP Growth is similar across all (around 6), no effect on GDP Growth

# %%
sns.barplot(x='bank', y='gdp_growth', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs GDP Growth")
plt.xlabel("Bank")
plt.ylabel("GDP Growth")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with slight variations
#  - The GDP Growth is similar across all (around 6), low effect on GDP Growth

# %%
sns.barplot(x='bank_type', y='gdp_growth', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs GDP Growth")
plt.xlabel("Bank Type")
plt.ylabel("GDP Growth")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types with slight variations
#  - The GDP Growth is similar across all (around 6), no effect on GDP Growth

# %%
sns.barplot(x='season', y='gdp_growth', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs GDP Growth")
plt.xlabel("Season")
plt.ylabel("GDP Growth")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The GDP Growth is similar across all (around 6), no effect on GDP Growth

# %%
sns.barplot(x='season', y='gdp_growth', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs GDP Growth")
plt.xlabel("Season")
plt.ylabel("GDP Growth")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The GDP Growth is similar across all (around 6), no effect on GDP Growth

# %% [raw]
# region, inflation_rate
# bank, inflation_rate
# bank_type, inflation_rate
# loan_type, inflation_rate

# %%
sns.barplot(x='region', y='inflation_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Inflation Rate")
plt.xlabel("Region")
plt.ylabel("Inflation Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The Inflation Rate is similar across all (around 5), low effect on Inflation Rate

# %%
sns.barplot(x='bank', y='inflation_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Inflation Rate")
plt.xlabel("Bank")
plt.ylabel("Inflation Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with slight variations
#  - The Inflation Rate is similar across all (around 5), no effect on Inflation Rate

# %%
sns.barplot(x='bank_type', y='inflation_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Inflation Rate")
plt.xlabel("Bank Type")
plt.ylabel("Inflation Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank types
#  - The Inflation Rate is similar across all (around 5), no effect on Inflation Rate

# %%
sns.barplot(x='loan_type', y='inflation_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Inflation Rate")
plt.xlabel("Loan Type")
plt.ylabel("Inflation Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Type
#  - The Inflation Rate is similar across all (around 5), low effect on Inflation Rate

# %%
sns.barplot(x='season', y='inflation_rate', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Inflation Rate")
plt.xlabel("Season")
plt.ylabel("Inflation Rate")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The Inflation Rate is similar across all (around 5), no effect on Inflation Rate

# %% [raw]
# region, consumer_confidence_index
# bank, consumer_confidence_index
# bank_type, consumer_confidence_index
# loan_type, consumer_confidence_index

# %%
sns.barplot(x='region', y='consumer_confidence_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Consumer Confidence Index")
plt.xlabel("Region")
plt.ylabel("Consumer Confidence Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The Consumer Confidence Index is similar across all (around 100), low effect on Consumer Confidence Index

# %%
sns.barplot(x='bank', y='consumer_confidence_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Consumer Confidence Index")
plt.xlabel("Bank")
plt.ylabel("Consumer Confidence Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with slight variations
#  - The Consumer Confidence Index is similar across all (around 100), no effect on Consumer Confidence Index

# %%
sns.barplot(x='bank_type', y='consumer_confidence_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Consumer Confidence Index")
plt.xlabel("Bank Type")
plt.ylabel("Consumer Confidence Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types
#  - The Consumer Confidence Index is similar across all (around 100), no effect on Consumer Confidence Index

# %%
sns.barplot(x='loan_type', y='consumer_confidence_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Consumer Confidence Index")
plt.xlabel("Loan Type")
plt.ylabel("Consumer Confidence Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Type
#  - The Consumer Confidence Index is similar across all (around 100), no effect on Consumer Confidence Index

# %%
sns.barplot(x='season', y='consumer_confidence_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Consumer Confidence Index")
plt.xlabel("Season")
plt.ylabel("Consumer Confidence Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The Consumer Confidence Index is similar across all (around 100), low effect on Consumer Confidence Index

# %% [raw]
# region, investment_sentiment
# bank, investment_sentiment
# bank_type, investment_sentiment
# loan_type, investment_sentiment

# %%
sns.barplot(x='region', y='investment_sentiment', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Investment Sentiment")
plt.xlabel("Region")
plt.ylabel("Investment Sentiment")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The Invest Sentiment is similar across all (around 60), no effect on Invest Sentiment

# %%
sns.barplot(x='bank', y='investment_sentiment', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Investment Sentiment")
plt.xlabel("Bank")
plt.ylabel("Investment Sentiment")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with slight variations
#  - The Invest Sentiment is similar across all (around 60), no effect on Invest Sentiment

# %%
sns.barplot(x='bank_type', y='investment_sentiment', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Investment Sentiment")
plt.xlabel("Bank Type")
plt.ylabel("Investment Sentiment")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all bank Types
#  - The Invest Sentiment is similar across all (around 60), no effect on Invest Sentiment

# %%
sns.barplot(x='loan_type', y='investment_sentiment', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Investment Sentiment")
plt.xlabel("Loan Type")
plt.ylabel("Investment Sentiment")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan type
#  - The Invest Sentiment is similar across all (around 60), no effect on Invest Sentiment

# %%
sns.barplot(x='season', y='investment_sentiment', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Investment Sentiment")
plt.xlabel("Season")
plt.ylabel("Investment Sentiment")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The Invest Sentiment is similar across all (around 60), no effect on Invest Sentiment

# %% [raw]
# region, npa_ratio
# bank, npa_ratio
# bank_type, npa_ratio
# loan_type, npa_ratio

# %%
sns.barplot(x='region', y='npa_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Npa Ratio")
plt.xlabel("Region")
plt.ylabel("Npa Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with high variations
#  - The Npa Ratio is not similar across all (around 0.49-0.54), high effect on Npa Ratio

# %%
sns.barplot(x='bank', y='npa_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Npa Ratio")
plt.xlabel("Bank")
plt.ylabel("Npa Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with high variations
#  - The Npa Ratio is not similar across all (around 0.49-0.54), high effect on Npa Ratio

# %%
sns.barplot(x='bank_type', y='npa_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Npa Ratio")
plt.xlabel("Bank Type")
plt.ylabel("Npa Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types
#  - The Npa Ratio is not similar across all (around 0.5), low effect on Npa Ratio

# %%
sns.barplot(x='loan_type', y='npa_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Npa Ratio")
plt.xlabel("Loan Type")
plt.ylabel("Npa Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types with slight variations
#  - The Npa Ratio is similar across all (around 0.49-0.54), low effect on Npa Ratio

# %%
sns.barplot(x='season', y='npa_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Npa Ratio")
plt.xlabel("Season")
plt.ylabel("Npa Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The Npa Ratio is similar across all (around 0.51), low effect on Npa Ratio

# %% [raw]
# region, liquidity_ratio
# bank, liquidity_ratio
# bank_type, liquidity_ratio
# loan_type, liquidity_ratio

# %%
sns.barplot(x='region', y='liquidity_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Liquidity Ratio")
plt.xlabel("Region")
plt.ylabel("Liquidity Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions
#  - The Liquidity Ratio is similar across all (around 120), no effect on Liquidity Ratio

# %%
sns.barplot(x='bank', y='liquidity_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Liquidity Ratio")
plt.xlabel("Bank")
plt.ylabel("Liquidity Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks
#  - The Liquidity Ratio is similar across all (around 120), no effect on Liquidity Ratio

# %%
sns.barplot(x='bank_type', y='liquidity_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Liquidity Ratio")
plt.xlabel("Bank Type")
plt.ylabel("Liquidity Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types
#  - The Liquidity Ratio is similar across all (around 120), no effect on Liquidity Ratio

# %%
sns.barplot(x='loan_type', y='liquidity_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Liquidity Ratio")
plt.xlabel("Loan Type")
plt.ylabel("Liquidity Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types
#  - The Liquidity Ratio is similar across all (around 120), no effect on Liquidity Ratio

# %%
sns.barplot(x='season', y='liquidity_ratio', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Liquidity Ratio")
plt.xlabel("Season")
plt.ylabel("Liquidity Ratio")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The Liquidity Ratio is similar across all (around 120), no effect on Liquidity Ratio

# %% [raw]
# region, global_trade_index
# bank, global_trade_index
# bank_type, global_trade_index
# loan_type, global_trade_index

# %%
sns.barplot(x='region', y='global_trade_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Global Trade Index")
plt.xlabel("Region")
plt.ylabel("Global Trade Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions
#  - The Global Trade Index is similar across all (around 100), no effect on Global Trade Index

# %%
sns.barplot(x='bank', y='global_trade_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Global Trade Index")
plt.xlabel("Bank")
plt.ylabel("Global Trade Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks
#  - The Global Trade Index is similar across all (around 100), no effect on Global Trade Index

# %%
sns.barplot(x='bank_type', y='global_trade_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Global Trade Index")
plt.xlabel("Bank Type")
plt.ylabel("Global Trade Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types
#  - The Global Trade Index is similar across all (around 100), no effect on Global Trade Index

# %%
sns.barplot(x='loan_type', y='global_trade_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Global Trade Index")
plt.xlabel("Loan Type")
plt.ylabel("Global Trade Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Loan Types
#  - The Global Trade Index is similar across all (around 100), no effect on Global Trade Index

# %%
sns.barplot(x='season', y='global_trade_index', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Global Trade Index")
plt.xlabel("Season")
plt.ylabel("Global Trade Index")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Seasons
#  - The Global Trade Index is similar across all (around 100), no effect on Global Trade Index

# %% [raw]
# region, bank_size
# bank, bank_size
# bank_type, bank_size
# loan_type, bank_size
# season,bank_size

# %%
sns.barplot(x='region', y='bank_size', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Bank Size")
plt.xlabel("Region")
plt.ylabel("Bank Size")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not balanced across all Regions with high variations
#  - The Bank Size is not similar across all (around 800000+-100000), high effect on Bank Size

# %%
sns.barplot(x='bank', y='bank_size', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Bank Size")
plt.xlabel("Bank")
plt.ylabel("Bank Size")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not balanced across all Banks with high variations
#  - The Bank Size is not similar across all (around 800000+-100000), high effect on Bank Size

# %%
sns.barplot(x='bank_type', y='bank_size', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Bank Size")
plt.xlabel("Bank Type")
plt.ylabel("Bank Size")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank types
#  - The Bank Size is similar across all (around 800000), no effect on Bank Size

# %%
sns.barplot(x='loan_type', y='bank_size', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Bank Size")
plt.xlabel("Loan Type")
plt.ylabel("Bank Size")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The Bank Size is similar across all (around 800000), low effect on Bank Size

# %%
sns.barplot(x='season', y='bank_size', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Bank Size")
plt.xlabel("Season")
plt.ylabel("Bank Size")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not balanced across all Regions with high variations
#  - The Bank Size is not similar across all (around 800000+-100000), high effect on Bank Size

# %% [raw]
# region, monthly_quarter
# bank, monthly_quarter
# bank_type, monthly_quarter
# loan_type, monthly_quarter
# season,monthly_quarter

# %%
sns.barplot(x='region', y='monthly_quarter', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Region vs Monthly Quarter")
plt.xlabel("Region")
plt.ylabel("Monthly Quarter")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Regions with slight variations
#  - The Monthly Quarter is similar across all (around 2.5), low effect on Monthly Quarter

# %%
sns.barplot(x='bank', y='monthly_quarter', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank vs Monthly Quarter")
plt.xlabel("Bank")
plt.ylabel("Monthly Quarter")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Banks with slight variations
#  - The Monthly Quarter is similar across all (around 2.5), low effect on Monthly Quarter

# %%
sns.barplot(x='bank_type', y='monthly_quarter', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Bank Type vs Monthly Quarter")
plt.xlabel("Bank Type")
plt.ylabel("Monthly Quarter")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all Bank Types with slight variations
#  - The Monthly Quarter is similar across all (around 2.5), low effect on Monthly Quarter

# %%
sns.barplot(x='loan_type', y='monthly_quarter', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Loan Type vs Monthly Quarter")
plt.xlabel("Loan Type")
plt.ylabel("Monthly Quarter")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced across all loan types
#  - The Monthly Quarter is similar across all (around 2.5), no effect on Monthly Quarter

# %%
sns.barplot(x='season', y='monthly_quarter', data=df_bank_loan_growth, color='#1f77b4', estimator='mean')
plt.title("Season vs Monthly Quarter")
plt.xlabel("Season")
plt.ylabel("Monthly Quarter")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not balanced across all Regions with high variations
#  - The Monthly Quarter is not similar across all (around 2.0-4.0), high effect on Monthly Quarter

# %% [markdown]
# ### Decide the target variable

# %%
# Check the data frame to decide the target variable
df_bank_loan_growth.head().T
# Out:
#                                         0               1               2  \
# region                     Andhra Pradesh  Andhra Pradesh  Andhra Pradesh
# bank                             Yes Bank        Yes Bank        Yes Bank
# bank_type                         Private         Private         Private
# year                                 2015            2015            2015
# month                                   1               2               3
# loan_type                          Retail            MSME          Retail
# credit_growth_rate               4.517568        2.218194        11.58288
# repo_rate                            7.75             6.0             4.0
# crr                                   3.0             3.5             3.5
# deposit_growth_rate              4.225131        5.123265        1.634815
# lending_rate                     11.22213        9.691752         6.86041
# gdp_growth                       5.103439        5.642978        7.737306
# ...

# %%
# Let's set lending_rate as target
target = df_bank_loan_growth.lending_rate

# After storing this variable into target we have to remove it from the main dataframe(Independant Variables)
df_bank_loan_growth = df_bank_loan_growth.drop('lending_rate', axis = 1)

# %%
df_num = df_bank_loan_growth.select_dtypes(include = 'number')

# %%
df_bank_loan_growth.columns
# Out:
# Index(['region', 'bank', 'bank_type', 'year', 'month', 'loan_type',
#        'credit_growth_rate', 'repo_rate', 'crr', 'deposit_growth_rate',
#        'gdp_growth', 'inflation_rate', 'consumer_confidence_index',
#        'investment_sentiment', 'npa_ratio', 'liquidity_ratio',
#        'global_trade_index', 'bank_size', 'monthly_quarter', 'season'],
#       dtype='object')

# %% [markdown]
# ## Prepare the Data for Machine Learning

# %% [markdown]
# ### Perform Encoding on Categorical Data

# %%
# Perform Encoding(one hot encoding)

df_encoded = pd.get_dummies(df_cat)

# %%
# Check the Encoded data

df_encoded.head()
# Out:
#    region_Andaman & Nicobar  region_Andhra Pradesh  region_Arunachal Pradesh  \
# 0                     False                   True                     False
# 1                     False                   True                     False
# 2                     False                   True                     False
# 3                     False                   True                     False
# 4                     False                   True                     False
#
#    region_Assam  region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 0         False         False              False                False
# 1         False         False              False                False
# 2         False         False              False                False
# 3         False         False              False                False
# 4         False         False              False                False
#
#    region_Dadra & Nagar Haveli  region_Delhi  region_Goa  ...  \
# ...

# %% [markdown]
# ### Scale the Numerical Columns

# %%
# Import the standard scaler sub package for performing the scaling
from sklearn.preprocessing import StandardScaler

# %%
# Initiate the standard scalar

ss = StandardScaler()

# %%
# Transform the numerical variables

scale=ss.fit_transform(df_num)

# Check the transformed data

scale
# Out:
# array([[-1.5806538 , -1.59644789, -1.08903008, ...,  0.37295406,
#          1.08215691, -1.34287821],
#        [-1.5806538 , -1.30651738, -1.54426578, ...,  0.02222944,
#          2.49025536, -1.34287821],
#        [-1.5806538 , -1.01658686,  0.30977807, ...,  0.34045815,
#         -0.45469272, -1.34287821],
#        ...,
#        [ 1.58291152,  1.01292676,  0.55542005, ...,  0.10790504,
#         -0.84774729,  1.34043754],
#        [ 1.58291152,  1.30285727, -0.95650126, ...,  0.10661879,
#          4.77748118,  1.34043754],
#        [ 1.58291152,  1.59278779,  0.21671935, ...,  1.30059541,
#         -0.09363724,  1.34043754]])

# %%
# Create a new dataframe for the scaled data

df_scaled = pd.DataFrame(scale, columns=df_num.columns)

# %%
# Check the scaled dataframe
df_scaled.head().T
# Out:
#                                   0         1         2         3         4
# year                      -1.580654 -1.580654 -1.580654 -1.580654 -1.580654
# month                     -1.596448 -1.306517 -1.016587  0.143135  0.433066
# credit_growth_rate        -1.089030 -1.544266  0.309778  0.860431  0.215428
# repo_rate                  1.425038 -0.002244 -1.633423 -0.206141 -0.206141
# crr                       -1.513641 -1.011553 -1.011553 -0.509465 -0.509465
# deposit_growth_rate       -0.930455 -0.708236 -1.571359  1.920333  0.511696
# gdp_growth                -0.390159 -0.157607  0.745090 -0.883623 -0.981200
# inflation_rate             1.230897 -0.974954 -1.373291 -1.090757  1.217740
# consumer_confidence_index -0.854514  0.344251 -0.685342 -1.428631  0.542917
# investment_sentiment      -0.725646  1.638964  1.486384  1.212700  0.701534
# npa_ratio                  0.883096  0.908920  1.055214 -0.257259  0.229519
# ...

# %% [markdown]
# ### Concatenate Both the Encoded and Scaled Dataframe

# %%
# Do the concatenation
X=pd.concat([df_encoded, df_scaled], axis=1)

# Check the concatenation data
X.head()
# Out:
#    region_Andaman & Nicobar  region_Andhra Pradesh  region_Arunachal Pradesh  \
# 0                     False                   True                     False
# 1                     False                   True                     False
# 2                     False                   True                     False
# 3                     False                   True                     False
# 4                     False                   True                     False
#
#    region_Assam  region_Bihar  region_Chandigarh  region_Chhattisgarh  \
# 0         False         False              False                False
# 1         False         False              False                False
# 2         False         False              False                False
# 3         False         False              False                False
# 4         False         False              False                False
#
#    region_Dadra & Nagar Haveli  region_Delhi  region_Goa  ...  \
# ...

# %% [markdown]
# ## Now split the Data in Training Set and Testing Set

# %%
# Import the train_test_split
from sklearn.model_selection import train_test_split

# %%
# create X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.2, random_state=42)

# %%
# Authentic chech for train set
print(X_train.shape)
print(y_train.shape)
# Out:
# (26679, 75)
# (26679,)

# %%
# Authentic check for test set
print(X_test.shape)
print(y_test.shape)
# Out:
# (6670, 75)
# (6670,)

# %% [markdown]
# ## Find the base ML Algorithm

# %% [markdown]
# ### Linear Regression

# %%
# Import linear regression algorithm and evaluation matrix
from sklearn.linear_model import LinearRegression

# here we are using MSE as evaluation matrix
from sklearn.metrics import mean_squared_error

# %%
# Create a linear regression model
model = LinearRegression()

# %%
# Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on the testing data
predictions = model.predict(X_test)

# %%
# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.3685533289147712

# %% [markdown]
# ### Ridge Model

# %%
from sklearn.linear_model import Ridge


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0)  # alpha is the regularization strength

# Fit the model to the training data
ridge_model.fit(X_train, y_train)

# Predict on the testing data
predictions = ridge_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.36842894266521814

# %% [markdown]
# ### Lasso Model

# %%
from sklearn.linear_model import Lasso

# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Lasso regression model
lasso_model = Lasso(alpha=1.0)  # alpha is the regularization strength

# Fit the model to the training data
lasso_model.fit(X_train, y_train)

# Predict on the testing data
predictions = lasso_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 1.363728163717389

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Decision Tree regression model
tree_model = DecisionTreeRegressor()

# Fit the model to the training data
tree_model.fit(X_train, y_train)

# Predict on the testing data
predictions = tree_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.7630924789807918

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Random Forest regression model
forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
forest_model.fit(X_train, y_train)

# Predict on the testing data
predictions = forest_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.38107494039771056

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a SVM regression model
svm_model = SVR(kernel='rbf')  # 'rbf' kernel is commonly used for non-linear regression

# Fit the model to the training data
svm_model.fit(X_train, y_train)

# Predict on the testing data
predictions = svm_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.41200937399189796

# %% [markdown]
# **Interpretation**
#  - As per this method I can conclude that Linear Regression is our base algorithm because it had the least MSE as comapared to other

# %% [markdown]
# ## Hyper parameter tuning using cross validation

# %%
# import numpy as np
# import pandas as pd
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import cross_val_score, KFold
# from sklearn.metrics import mean_squared_error, make_scorer
# from sklearn.preprocessing import StandardScaler

# # Assuming you already have your dataset as X (features) and y (target)
# # X = df.drop(columns=["target"])
# # y = df["target"]

# # Standardize features (optional but useful if variables are on different scales)
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Define model
# model = LinearRegression()

# # Define K-Fold CV
# kf = KFold(n_splits=5, shuffle=True, random_state=42)

# # Define scorer for MSE
# mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)

# # Perform cross-validation
# mse_scores = cross_val_score(model, X_scaled, target, scoring=mse_scorer, cv=kf)

# # Report results
# print("Cross-validated MSE scores:", -mse_scores)  # Negate to show positive MSE
# print("Average MSE:", -np.mean(mse_scores))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Initialize the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Step 2: Initialize RFE (select top 38 features)
rfe = RFE(estimator=rf_model, n_features_to_select=20)

# Step 3: Fit RFE on training data
rfe.fit(X_train, y_train)

# Step 4: Get the selected features
selected_features = X_train.columns[rfe.support_]
print("Selected Features:", selected_features.tolist())

# Step 5: Train the Random Forest model on selected features
rf_model.fit(X_train[selected_features], y_train)

# Step 6: Predict on test data using selected features
y_pred = rf_model.predict(X_test[selected_features])

# Step 7: Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Selected Features: ['bank_type_Public', 'loan_type_Corporate', 'loan_type_MSME', 'loan_type_Retail', 'season_Monsoon', 'year', 'month', 'credit_growth_rate', 'repo_rate', 'crr', 'deposit_growth_rate', 'gdp_growth', 'inflation_rate', 'consumer_confidence_index', 'investment_sentiment', 'npa_ratio', 'liquidity_ratio', 'global_trade_index', 'bank_size', 'monthly_quarter']
# Mean Squared Error: 0.3816628549330523
# R² Score: 0.7954613958446711

# %%
# Save the model and RFE selector using joblib
import joblib
joblib.dump(rf_model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
joblib.dump(selected_features, 'rfe_selector.pkl')
# Out:
# ['rfe_selector.pkl']
